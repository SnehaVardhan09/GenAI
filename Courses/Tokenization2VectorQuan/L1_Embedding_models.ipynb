# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")
model
# Out:
# Error importing huggingface_hub.hf_api: cannot import name 'logging' from 'huggingface_hub' (c:\Users\navee\anaconda3\envs\ml\lib\site-packages\huggingface_hub\__init__.py)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       3 model = SentenceTransformer("all-MiniLM-L6-v2")
#       4 model
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\sentence_transformers\__init__.py:10
#       7 import os
#       9 from sentence_transformers.backend import export_dynamic_quantized_onnx_model, export_optimized_onnx_model
# ---> 10 from sentence_transformers.cross_encoder.CrossEncoder import CrossEncoder
#      11 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      12 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       5 __all__ = ["CrossEncoder"]
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:14
#      12 from torch.utils.data import DataLoader
#      13 from tqdm.autonotebook import tqdm, trange
# ---> 14 from transformers import AutoConfig, AutoModelForSequenceClassification, AutoTokenizer, is_torch_npu_available
#      15 from transformers.tokenization_utils_base import BatchEncoding
#      16 from transformers.utils import PushToHubMixin
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\transformers\__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\transformers\utils\__init__.py:21
#      18 from functools import lru_cache
#      19 from typing import FrozenSet
# ---> 21 from huggingface_hub import get_full_repo_name  # for backward compatibility
#      22 from huggingface_hub.constants import HF_HUB_DISABLE_TELEMETRY as DISABLE_TELEMETRY  # for backward compatibility
#      23 from packaging import version
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\huggingface_hub\__init__.py:530, in _attach.<locals>.__getattr__(name)
#     528 submod_path = f"{package_name}.{attr_to_modules[name]}"
#     529 try:
# --> 530     submod = importlib.import_module(submod_path)
#     531 except Exception as e:
#     532     print(f"Error importing {submod_path}: {e}")
#
# File c:\Users\navee\anaconda3\envs\ml\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\huggingface_hub\hf_api.py:52
#      49 from tqdm.contrib.concurrent import thread_map
#      51 from . import constants
# ---> 52 from ._commit_api import (
#      53     CommitOperation,
#      54     CommitOperationAdd,
#      55     CommitOperationCopy,
#      56     CommitOperationDelete,
#      57     _fetch_files_to_copy,
#      58     _fetch_upload_modes,
#      59     _prepare_commit_payload,
#      60     _upload_lfs_files,
#      61     _warn_on_overwriting_operations,
#      62 )
#      63 from ._inference_endpoints import InferenceEndpoint, InferenceEndpointType
#      64 from ._multi_commits import (
#      65     MULTI_COMMIT_PR_CLOSE_COMMENT_FAILURE_BAD_REQUEST_TEMPLATE,
#      66     MULTI_COMMIT_PR_CLOSE_COMMENT_FAILURE_NO_CHANGES_TEMPLATE,
#    (...)
#      75     plan_multi_commits,
#      76 )
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\huggingface_hub\_commit_api.py:20
#      18 from . import constants
#      19 from .errors import EntryNotFoundError
# ---> 20 from .file_download import hf_hub_url
#      21 from .lfs import UploadInfo, lfs_upload, post_lfs_batch_info
#      22 from .utils import (
#      23     FORBIDDEN_FOLDERS,
#      24     chunk_iterable,
#    (...)
#      30     validate_hf_hub_args,
#      31 )
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\huggingface_hub\file_download.py:25
#      19 import requests
#      21 from . import (
#      22     __version__,  # noqa: F401 # for backward compatibility
#      23     constants,
#      24 )
# ---> 25 from ._local_folder import (
#      26     get_local_download_paths,
#      27     read_download_metadata,
#      28     write_download_metadata,
#      29 )
#      30 from .constants import (
#      31     HUGGINGFACE_CO_URL_TEMPLATE,  # noqa: F401 # for backward compatibility
#      32     HUGGINGFACE_HUB_CACHE,  # noqa: F401 # for backward compatibility
#      33 )
#      34 from .errors import (
#      35     EntryNotFoundError,
#      36     FileMetadataError,
#    (...)
#      40     RevisionNotFoundError,
#      41 )
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\huggingface_hub\_local_folder.py:60
#      57 from pathlib import Path
#      58 from typing import Optional
# ---> 60 from .utils import WeakFileLock
#      63 logger = logging.getLogger(__name__)
#      66 @dataclass
#      67 class LocalDownloadFilePaths:
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\huggingface_hub\utils\__init__.py:112
#     106 from ._safetensors import (
#     107     SafetensorsFileMetadata,
#     108     SafetensorsRepoMetadata,
#     109     TensorInfo,
#     110 )
#     111 from ._subprocess import capture_output, run_interactive_subprocess, run_subprocess
# --> 112 from ._telemetry import send_telemetry
#     113 from ._token import get_token
#     114 from ._typing import is_jsonable, is_simple_optional_type, unwrap_simple_optional_type
#
# File c:\Users\navee\anaconda3\envs\ml\lib\site-packages\huggingface_hub\utils\_telemetry.py:6
#       3 from typing import Dict, Optional, Union
#       4 from urllib.parse import quote
# ----> 6 from .. import constants, logging
#       7 from . import build_hf_headers, get_session, hf_raise_for_status
#      10 logger = logging.get_logger(__name__)
#
# ImportError: cannot import name 'logging' from 'huggingface_hub' (c:\Users\navee\anaconda3\envs\ml\lib\site-packages\huggingface_hub\__init__.py)
